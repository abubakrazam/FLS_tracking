# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from glob import glob
import pandas as pd

# %%
files=sorted(glob("*.csv"))
files
# Out:
# ['output_02_19-12_11_36_0.csv', 'output_02_19_12_13_39.csv']

# %%
df1=pd.read_csv(files[1])
df2=pd.read_csv(files[0])

# %%
plt.plot(df2["Sonar_Distance_2"][7:42])

# %%
plt.plot(df2["Sonar_Distance_1"][7:42])

# %%
plt.scatter(df1["Sonar_Distance_1"][150:320]/1000,df1["Sonar_Distance_2"][150:320]/1000,label="Trial 1 (Longer)")
plt.scatter(df2["Sonar_Distance_1"][7:42]/1000,df2["Sonar_Distance_2"][7:42]/1000,label="Trial 2 (Shorter)")
plt.ylabel("SBS_Distance_Surge (m)")
plt.xlabel("SBS_Distance_Sway (m)")
plt.legend()
#plt.xlim(0,15)
